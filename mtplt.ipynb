# %% [markdown]
# # MATPLOTLIB TUT

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=np.arange(20)
y=np.arange(20)
plt.plot(x,y,'*')
plt.show()

# %%
x=np.array([3,6])
y=np.array([5,7])
plt.plot(x,y,'o')
plt.show()

# %%
x=np.array([2,4,5,6,8,10])
y=np.array([3,5,2,7,9,10])
plt.plot(x,y)
plt.show()

# %%
y=np.array([3,8,1,10,5,7])
x=np.array([0,0,0,0,0,0])
plt.plot(x,y,'o')
plt.show()

# %%
point=np.array([3,8,1,10])
plt.plot(point,marker="o")
plt.show()

# %%
x=np.array([3,8,1,10])
plt.plot(x,'o:k')  # o for marker   : --> type of line dotted - (solid line)
plt.show()         # -- (dashed line)  -. (dashed/dotted line)
                   # k --> color k(black),b(blue),y(yellow)...etc

# %%
x=np.array([3,8,1,10])
plt.plot(x, marker='o',ms=20)  # ms -->  marker size 
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 20, mec = 'r')
#ms= marker size , mec= marker edge color
plt.show()

# %%
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints, marker = 'o', ms = 10, mec = 'black', mfc = 'hotpink')
#ms= marker size , mec= marker edge color
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x=([10,12,15,17,18,20])
y=([12,14,15,16,19,22])
plt.plot(x,y,'X--r',mec='k',ms=10,mfc='pink')
plt.xlabel("label x",c="b",size=15)
plt.ylabel("label y")
plt.title("this is my title",c="red",loc="right",size=45)
plt.show()

# %%
a=str("rishabh")
print(a)
# Out:
# rishabh

# %%
type(a)
# Out:
# str

# %%
v="rish"
c="abh"
d=str(v)+str(c)
d
# Out:
# 'rishabh'

# %%
import pandas as pd
a=pd.read_json("C:\\Users\\Lenovo\\Downloads\\archive (5)\\iris.json")
a.head()
# Out:
#    sepalLength  sepalWidth  petalLength  petalWidth species
# 0          5.1         3.5          1.4         0.2  setosa
# 1          4.9         3.0          1.4         0.2  setosa
# 2          4.7         3.2          1.3         0.2  setosa
# 3          4.6         3.1          1.5         0.2  setosa
# 4          5.0         3.6          1.4         0.2  setosa

# %%
a["sepalWidth"].head()
# Out:
# 0    3.5
# 1    3.0
# 2    3.2
# 3    3.1
# 4    3.6
# Name: sepalWidth, dtype: float64

# %%
a['petalLength'].head()
# Out:
# 0    1.4
# 1    1.4
# 2    1.3
# 3    1.5
# 4    1.4
# Name: petalLength, dtype: float64

# %%
x=([10,12,15,17,18,20])
y=([12,14,15,16,19,22])
plt.plot(x,y,'X--r',mec='k',ms=10,mfc='pink')
plt.xlabel("label x",c="b",size=15)
plt.ylabel("label y")
plt.title("this is my title",c="red",loc="right",size=45)
plt.grid()
plt.show()

# %%
x=([10,12,15,17,18,20])
y=([12,14,15,16,19,22])
plt.plot(x,y,'X--r',mec='k',ms=10,mfc='pink')
plt.xlabel("label x",c="b",size=15)
plt.ylabel("label y")
plt.title("this is my title",c="red",loc="center",size=20)
plt.grid(axis="y")
plt.show()

# %%
x=([10,12,15,17,18,20])
y=([12,14,15,16,19,22])
plt.plot(x,y,'X--r',mec='k',ms=15,mfc='pink')
plt.xlabel("label x",c="b",size=15)
plt.ylabel("label y")
plt.title("TITLE",c="red",loc="center",size=20)
plt.grid(color="green",linestyle='--',linewidth=2)
plt.show()

# %% [markdown]
# # SUB PLOT

# %%
x=np.array([2,4,6,8])
y=np.array([1,3,4,9])

plt.subplot(3, 1, 1)
plt.plot(x,y,marker='X',ms=10,c='g')
plt.grid()
plt.plot(x,y)
#graph 2

x=np.array([1,3,5,7])
y=np.array([5,7,9,11])
plt.subplot(3, 1, 2)
plt.plot(x,y)


plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)
#plot3:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 3)
plt.plot(x,y)

#plot4
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

plt.show()

# %%
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 1)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 2)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 3)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 4)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])

plt.subplot(2, 3, 5)
plt.plot(x,y)

x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])

plt.subplot(2, 3, 6)
plt.plot(x,y)
plt.legend(['legend'])

plt.show()

# %%
x=np.array([24,28,34,42])
y=np.array([22,14,16,42])
plt.subplot(2,3,1)
plt.title('my graph 1')
plt.plot(x,y)

x=np.array([2,6,7,9])
y=np.array([5,8,9,5])
plt.subplot(3,3,2)
plt.grid(color='green',linestyle='--',axis='y')
plt.title('my graph 2')
plt.plot(x,y)

# %% [markdown]
# # Scatter Plot

# %%
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])

plt.scatter(x, y,color='green')
plt.show()

# %%
x=np.array([2,5,14,16,24,28,30,34])
y=np.array([2,4,15,19,23,24,36,38])
plt.scatter(x,y,color='red')

a=np.array([15,28,46,8,54,48])
b=np.arange(18,24)
plt.scatter(a,b,color='blue',s=100)

plt.show()

# %%
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
colors=np.random.randint(100,size=(100))

plt.scatter(x,y,c=colors,cmap='GnBu')
plt.colorbar()
plt.show()

# %%
x=np.random.randint(100,size=(100))
y=np.random.randint(100,size=(100))
colors=np.random.randint(100,size=(100))

plt.scatter(x,y,c=colors,cmap='Accent_r')
plt.colorbar()
plt.show()

# %%
x=np.array([5,7,8,7,2,12,45,47,15,35])
y=np.array([10,8,14,7,5,8,14,65,47,54,])
sizes=np.array([20,50,100,200,500,250,100,45,400,355])

plt.scatter(x,y,s=sizes,c='green',alpha=0.5)
plt.colorbar()
plt.show()

# %%
x = np.random.randint(100, size=(100))
y = np.random.randint(100, size=(100))
colors = np.random.randint(100, size=(100))
sizes = 10 * np.random.randint(100, size=(100))

plt.scatter(x, y, c=colors, s=sizes, alpha=0.5, cmap='nipy_spectral')

plt.colorbar()

plt.show()

# %% [markdown]
# # Bar Plot

# %%
x=np.array(["A","B","C","D"])
y=np.array([20,15,30,40])

plt.bar(x,y,color="violet")
plt.title("This is my Title",size=40,color='orange')
plt.xlabel("this is my label on x-axix",size=20,color='hotpink')
plt.ylabel("this is my label on y-axix",size=20,color='green')
plt.show()

# %% [markdown]
# # plotting the bar plot horizontally using- plt.barh

# %%
x=np.array(["apple","mango","guava","orange"])
y=np.array([160,220,70,90])
c=np.array(['red','yellow','hotpink','orange'])
plt.barh(x,y,color=c)
plt.ylabel("Fruits ",color='orange',size=20)
plt.xlabel("prices",color='red',size=20)
plt.plot()
# Out:
# []

# %%
x=np.array(["apple","mango","guava","orange"])
y=np.array([160,220,70,90])
c=np.array(['red','yellow','hotpink','orange'])
plt.bar(x,y,color=c)
plt.ylabel("Fruits ",color='orange',size=20)
plt.xlabel("prices",color='red',size=20)

plt.plot()
# Out:
# []

# %%
x=np.array(["apple","mango","guava","orange"])
y=np.array([160,220,70,90])

plt.bar(x,y,width=0.2)#width function is used in the bar
plt.plot()
# Out:
# []

# %%
x=np.array(["apple","mango","guava","orange"])
y=np.array([160,220,70,90])

plt.barh(x,y,height=0.5)#height function is used in the barh
plt.plot()
# Out:
# []

# %% [markdown]
# # Histogram Gram

# %%
x = np.random.normal(170, 2, 20)
print(x)
# Out:
# [168.38839628 170.60378613 169.9154112  166.18767344 172.03515336
#  169.63651013 171.07296166 167.03772007 169.76343664 171.46252945
#  172.63928694 169.86853577 170.41794872 169.52597363 169.4604856
#  171.92168731 172.62233215 170.145362   171.61010633 169.61368773]

# %% [markdown]
# # Pie Chart

# %%
x=np.array([15,10,10,5,30,15])
plt.pie(x) 
plt.plot()
# Out:
# []

# %%
y = np.array([50,50,50,50])
plt.pie(y,explode=[0.2,0,0,0],shadow=True)
plt.show()

# %%
np.array([])
label=np.array(['apple','mango','banana','guava','chiku''grapes','cherry','lichi','strawberry'])

# %%
y=np.array([20,40,30,10])
my_labels=["A","B","C","D"]

plt.pie(y,labels=my_labels,shadow=True,explode=[0,0,0,0])
#a=plt.legend(title='my',loc='upper left')
plt.show()

# %%
plt.figure(figsize=(3,3),dpi=100)
x2=np.arange(0,4.5,0.5)
plt.plot(x2[:6],x2[:6]**2,'k')
plt.plot(x2[5:],x2[5:]**2,'r--')

plt.show()

# %%
x=([10,12,15,17,18,20])
y=([12,14,15,16,19,22])
plt.figure(figsize=(6,4),dpi=70)
plt.plot(x,y,marker='X',linestyle='--',ms=10,mfc='pink',mec='k',label="blue")
plt.title("try graph")

#line 2
x=np.array([20,15,18,13,4,8,16])
y=np.array([20,15,18,13,4,8,16])
plt.plot(x,y,color="orange",label="orange")

plt.grid(color="g")
plt.legend(loc='lower right')
plt.xticks(np.arange(0,30,5))#for increasing the x axis gap
plt.yticks(np.arange(0,30,5))#for increasing the y axis gap
plt.show()

# %%
x=([10,12,15,17,18,20])
y=([12,14,15,16,19,22])
plt.plot(x,y,'X--r',mec='k',ms=15,mfc='pink')
plt.xlabel("label x",c="b",size=15)
plt.ylabel("label y",size=15, fontdict={'fontname':'comic sans ms'})
plt.title("TITLE",c="red",loc="center",size=20, fontdict={'fontname':'comic sans ms'})
plt.grid(color="green",linestyle='--',linewidth=2)
plt.savefig("mymatplotgraph.png",dpi=300)
plt.show()

# %% [markdown]
# # Bar chart

# %%
labels=['A','B','C']
values=[1,4,2]
bars=plt.bar(labels,values)
patterns=['/','o','*']

# bars[0].set_hatch('/')
# bars[1].set_hatch('o')
# bars[2].set_hatch('*')
for bar in bars:
    bar.set_hatch(patterns.pop(0))
plt.show()

# %%
labels=['A','B','C']
x = [1, 3, 2]
y = [2, 4, 3]
z = [7, 6, 8]
a=np.arange(3)
fig = plt.subplots(figsize =(10, 7))
plt.bar(a,x,color='y')
plt.bar(a,y,color='g',bottom=x)
plt.bar(a,z,color='r',bottom=y)
plt.yticks(np.arange(0,10))
plt.show()

# %%
x = [1, 3, 2]
y = [2, 3, 3]
z = [7, 6, 8]

# Standard deviation rates for error bars
x_deviation = np.std(x)
y_deviation = np.std(y)
z_deviation = np.std(z)

bars = [x, y, z]
ind = np.arange(len(bars))
bar_categories = ['X', 'Y', 'Z'];
bar_width = 0.5
bar_padding = np.add(x, y).tolist()


plt.bar(ind, x, yerr=x_deviation, width=bar_width)
plt.bar(ind, y, yerr=y_deviation, bottom=x, width=bar_width)
plt.bar(ind, z, yerr=z_deviation, bottom=bar_padding, width=bar_width)

plt.xticks(ind, bar_categories)
plt.xlabel("Stacked Bar Plot")

plt.show()

# %%
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
b=np.arange(10,80,5  )
plt.hist(a, bins = b )
plt.title("histogram of result")
# plt.xticks([0,25,50,75,100])
plt.xlabel('marks')
plt.ylabel('no. of students')
plt.show()

# %%
import seaborn as sns

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
data=sns.load_dataset("penguins")
data.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %%
min=data['body_mass_g'].min()
min
# Out:
# 2700.0

# %%
data['body_mass_g'].max()
# Out:
# 6300.0

# %%
data['body_mass_g'].mean()
# Out:
# 4201.754385964912

# %%
min_w=data[data['body_mass_g']>4200].count()[0]
max_w=data[data['body_mass_g']<4200].count()[0]
avg_w=data[data['body_mass_g']==4200].count()[0]
plt.figure(figsize=[10,8])
color=["red","green",'blue']
explodes=[0,0.05,0.4]
mylabels=['min_weight','max_weight','avg_weight']
plt.pie([min_w,max_w,avg_w],colors=color,autopct="%.2f%%",explode=explodes,labels=mylabels)
plt.title("Penguine Weight Analyser",fontdict={'fontweight':'bold','fontsize':20})
plt.legend(loc='upper left')
plt.show()
